# %%
# !ls
# Out:
# ' accuracy_test.ipynb'		        s_mysql_220503.ipynb
#  data				        s_mysql_aod_pred_insert.ipynb
#  LinearRegression_s_pred_model.pickle   solar_code_test_0506.ipynb
#  mysql_insert_final_0511.ipynb	        s_pred_model_0504.ipynb
#  s_aod_pred_model_0504.ipynb	        time_series_LinearRegression_0510.ipynb
#  s_aod_pred_model_0506.ipynb	        time_series_lstm_0510.ipynb
#  s_data_220502.ipynb		        time_series_model_0510.ipynb
#  s_LinearRegression_model_0511.ipynb

# %%
# %cd drive/MyDrive/Colab\ Notebooks/2022-04-27\ 데이터
# Out:
# /content/drive/MyDrive/Colab Notebooks/2022-04-27 데이터

# %%
# !sudo apt-get install python3-dev default-libmysqlclient-dev
# !pip install pymysql
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# default-libmysqlclient-dev is already the newest version (1.0.4).
# python3-dev is already the newest version (3.6.7-1~18.04).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Requirement already satisfied: pymysql in /usr/local/lib/python3.7/dist-packages (1.0.2)

# %%
import pandas as pd
import numpy as np
import pymysql # mysql 연결
import pickle # 모델 불러올 때 사용
from datetime import date, datetime, timezone, timedelta # 시간 관련 라이브러리
import pickle

# %%
# 모델 불러오기
with open('LinearRegression_s_pred_model.pickle', 'rb') as f:
    s_model = pickle.load(f)

# %%
# 시간 맞추기
# hours=9 는 현재 한국시간
# 우리는 한 시간 후의 시간을 불러와야 하기 때문에 hours=10 으로 설정
K_KST = timezone(timedelta(hours=9))
H_KST = timezone(timedelta(hours=10))

# %%
# DB 연결
from pymysql.converters import convert_bit
host = "project-db-stu.ddns.net"
port = 3307
username = "wish"
password = "1234"
db = 'wish'

conn = pymysql.connect(host=host, port=port, user=username, password=password, db=db)

# select 현재 시간, 데이터 번호 (real_data의 마지막 데이터 불러오기)
sql_state1 = f"select r_seq, r_date, r_aod from s_real_data order by r_date desc limit 1"
s_real = pd.read_sql_query(sql_state1, conn)
s_r_seq = s_real['r_seq']
s_r_date = s_real['r_date']
s_r_now_aod = s_real['r_aod']

print(f"s_r_now_aod : {s_r_now_aod[0]}")

# 불러온 데이터의 시간 추출
s_now_time = f"{s_r_date[0]}"
print(f"s_now_time : {s_now_time}")


# s_now_time 의 한 시간 후의 시간
s_now_time_slice = s_now_time[:18]
s_pred_t = (int)(s_now_time_slice[11:13]) + 1
print(f"s_pred_t : {s_pred_t}")

if s_pred_t < 10:
  s_pred_t = f"0{s_pred_t}"

timeList = list(s_now_time)
timeList[11:13] = f"{s_pred_t}"
s_pred_time = ''.join(s for s in timeList)
s_pred_time_slice = s_pred_time[:18]
print(f"s_pred_time : {s_pred_time}")
print(f"s_pred_time_slice : {s_pred_time_slice}")

# s_now_time 의 한 시간 전의 시간
s_before_t = (int)(s_now_time_slice[11:13]) - 1
print(f"s_before_t : {s_before_t}")

if s_before_t < 10:
  s_before_t = f"0{s_before_t}"

timeList[11:13] = f"{s_before_t}"
s_before_time = ''.join(s for s in timeList)
s_before_time_slice = s_before_time[:18]
print(f"s_before_time_slice : {s_before_time_slice}")

# select 한 시간 후의 날씨
sql_state2 = f"select * from temp_weather where date_time like '{s_pred_time_slice}%'"
s_after_weather = pd.read_sql_query(sql_state2, conn)
after_hour_weather = pd.DataFrame(s_after_weather)

# select 한 시간 전의 발전량
sql_state3 = f"select r_aod from s_real_data where r_date like '{s_before_time_slice}%'"
s_before_aod = pd.read_sql_query(sql_state3, conn)
before_hour_aod = s_before_aod['r_aod']
print(f"before_hour_aod : {before_hour_aod}")

# 모델에 넣을 데이터 형식 맞추기
after_hour_weather['now_aod'] = s_r_now_aod[0]
after_hour_weather['before_aod'] = before_hour_aod[0]

test = after_hour_weather.loc[:, 'temperature':]
X_test = np.array(test)
print(X_test)

pred_aod = s_model.predict(X_test)
s_pred_aod = pred_aod[0]

print(f"s_pred_aod : {s_pred_aod}")

if s_pred_aod < 0 :
  s_pred_aod = 0

print(s_pred_time)

s_pred_time_n = datetime.strptime(s_pred_time, '%Y-%m-%d %H:%M:%S')
print(f"s_pred_time_n : {s_pred_time_n}")

# DB insert into s_predict
sql_state3 = f"insert into s_prediction values (null, {s_r_seq[0]}, '{s_pred_time_n}', {s_pred_aod[0]})"
cursor = conn.cursor()
cursor.execute(sql_state3)
conn.commit()
# Out:
# s_r_now_aod : 287
# s_now_time : 2022-05-11 15:25:03
# s_pred_t : 16
# s_pred_time : 2022-05-11 16:25:03
# s_pred_time_slice : 2022-05-11 16:25:0
# s_before_t : 14
# s_before_time_slice : 2022-05-11 14:25:0
# before_hour_aod : 0    426
# Name: r_aod, dtype: int64
# [[3.0000e+01 0.0000e+00 1.1000e+00 6.1400e+01 3.0000e-01 0.0000e+00
#   1.9999e+03 3.4400e+01 2.8700e+02 4.2600e+02]]
# s_pred_aod : [123.34211899]
# 2022-05-11 16:25:03
# s_pred_time_n : 2022-05-11 16:25:03

# %%
def pred():
  # DB 연결
  from pymysql.converters import convert_bit
  host = "project-db-stu.ddns.net"
  port = 3307
  username = "wish"
  password = "1234"
  db = 'wish'

  conn = pymysql.connect(host=host, port=port, user=username, password=password, db=db)

  # select 현재 시간, 데이터 번호 (real_data의 마지막 데이터 불러오기)
  sql_state1 = f"select r_seq, r_date, r_aod from s_real_data order by r_date desc limit 1"
  s_real = pd.read_sql_query(sql_state1, conn)
  s_r_seq = s_real['r_seq']
  s_r_date = s_real['r_date']
  s_r_now_aod = s_real['r_aod']

  print(f"s_r_now_aod : {s_r_now_aod[0]}")

  # 불러온 데이터의 시간 추출
  s_now_time = f"{s_r_date[0]}"
  print(f"s_now_time : {s_now_time}")


  # s_now_time 의 한 시간 후의 시간
  s_now_time_slice = s_now_time[:18]
  s_pred_t = (int)(s_now_time_slice[11:13]) + 1
  print(f"s_pred_t : {s_pred_t}")

  if s_pred_t < 10:
    s_pred_t = f"0{s_pred_t}"

  timeList = list(s_now_time)
  timeList[11:13] = f"{s_pred_t}"
  s_pred_time = ''.join(s for s in timeList)
  s_pred_time_slice = s_pred_time[:18]
  print(f"s_pred_time : {s_pred_time}")
  print(f"s_pred_time_slice : {s_pred_time_slice}")

  # s_now_time 의 한 시간 전의 시간
  s_before_t = (int)(s_now_time_slice[11:13]) - 1
  print(f"s_before_t : {s_before_t}")

  if s_before_t < 10:
    s_before_t = f"0{s_before_t}"

  timeList[11:13] = f"{s_before_t}"
  s_before_time = ''.join(s for s in timeList)
  s_before_time_slice = s_before_time[:18]
  print(f"s_before_time_slice : {s_before_time_slice}")

  # select 한 시간 후의 날씨
  sql_state2 = f"select * from temp_weather where date_time like '{s_pred_time_slice}%'"
  s_after_weather = pd.read_sql_query(sql_state2, conn)
  after_hour_weather = pd.DataFrame(s_after_weather)

  # select 한 시간 전의 발전량
  sql_state3 = f"select r_aod from s_real_data where r_date like '{s_before_time_slice}%'"
  s_before_aod = pd.read_sql_query(sql_state3, conn)
  before_hour_aod = s_before_aod['r_aod']
  print(f"before_hour_aod : {before_hour_aod}")

  # 모델에 넣을 데이터 형식 맞추기
  after_hour_weather['now_aod'] = s_r_now_aod[0]
  after_hour_weather['before_aod'] = before_hour_aod[0]

  test = after_hour_weather.loc[:, 'temperature':]
  X_test = np.array(test)
  print(X_test)

  pred_aod = s_model.predict(X_test)
  s_pred_aod = pred_aod[0]

  print(f"s_pred_aod : {s_pred_aod}")

  if s_pred_aod < 0 :
    s_pred_aod = 0

  print(s_pred_time)

  s_pred_time_n = datetime.strptime(s_pred_time, '%Y-%m-%d %H:%M:%S')
  print(f"s_pred_time_n : {s_pred_time_n}")

  # DB insert into s_predict
  sql_state3 = f"insert into s_prediction values (null, {s_r_seq[0]}, '{s_pred_time_n}', {s_pred_aod[0]})"
  cursor = conn.cursor()
  cursor.execute(sql_state3)
  conn.commit()

  threading.Timer(10, pred).start()

# %%
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.1.0

# %%
import time
import schedule
import threading

# %%
pred()
# Out:
# s_r_now_aod : 247
# s_now_time : 2022-05-11 15:52:00
# s_pred_t : 16
# s_pred_time : 2022-05-11 16:52:00
# s_pred_time_slice : 2022-05-11 16:52:0
# s_before_t : 14
# s_before_time_slice : 2022-05-11 14:52:0
# before_hour_aod : 0    347
# Name: r_aod, dtype: int64
# [[2.99e+01 0.00e+00 9.00e-01 6.98e+01 4.00e-01 0.00e+00 2.00e+03 3.44e+01
#   2.47e+02 3.47e+02]]
# s_pred_aod : [135.50444608]
# 2022-05-11 16:52:00
# s_pred_time_n : 2022-05-11 16:52:00

# %%
while True:
  # DB 연결
  from pymysql.converters import convert_bit
  host = "project-db-stu.ddns.net"
  port = 3307
  username = "wish"
  password = "1234"
  db = 'wish'

  conn = pymysql.connect(host=host, port=port, user=username, password=password, db=db)

  # select 현재 시간, 데이터 번호 (real_data의 마지막 데이터 불러오기)
  sql_state1 = f"select r_seq, r_date, r_aod from s_real_data order by r_date desc limit 1"
  s_real = pd.read_sql_query(sql_state1, conn)
  s_r_seq = s_real['r_seq']
  s_r_date = s_real['r_date']
  s_r_now_aod = s_real['r_aod']

  print(f"s_r_now_aod : {s_r_now_aod[0]}")

  # 불러온 데이터의 시간 추출
  s_now_time = f"{s_r_date[0]}"
  print(f"s_now_time : {s_now_time}")


  # s_now_time 의 한 시간 후의 시간
  s_now_time_slice = s_now_time[:18]
  s_pred_t = (int)(s_now_time_slice[11:13]) + 1
  print(f"s_pred_t : {s_pred_t}")

  if s_pred_t < 10:
    s_pred_t = f"0{s_pred_t}"

  timeList = list(s_now_time)
  timeList[11:13] = f"{s_pred_t}"
  s_pred_time = ''.join(s for s in timeList)
  s_pred_time_slice = s_pred_time[:18]
  print(f"s_pred_time : {s_pred_time}")
  print(f"s_pred_time_slice : {s_pred_time_slice}")

  # s_now_time 의 한 시간 전의 시간
  s_before_t = (int)(s_now_time_slice[11:13]) - 1
  print(f"s_before_t : {s_before_t}")

  if s_before_t < 10:
    s_before_t = f"0{s_before_t}"

  timeList[11:13] = f"{s_before_t}"
  s_before_time = ''.join(s for s in timeList)
  s_before_time_slice = s_before_time[:18]
  print(f"s_before_time_slice : {s_before_time_slice}")

  # select 한 시간 후의 날씨
  sql_state2 = f"select * from temp_weather where date_time like '{s_pred_time_slice}%'"
  s_after_weather = pd.read_sql_query(sql_state2, conn)
  after_hour_weather = pd.DataFrame(s_after_weather)

  # select 한 시간 전의 발전량
  sql_state3 = f"select r_aod from s_real_data where r_date like '{s_before_time_slice}%'"
  s_before_aod = pd.read_sql_query(sql_state3, conn)
  before_hour_aod = s_before_aod['r_aod']
  print(f"before_hour_aod : {before_hour_aod}")

  # 모델에 넣을 데이터 형식 맞추기
  after_hour_weather['now_aod'] = s_r_now_aod[0]
  after_hour_weather['before_aod'] = before_hour_aod[0]

  test = after_hour_weather.loc[:, 'temperature':]
  X_test = np.array(test)
  print(X_test)

  pred_aod = s_model.predict(X_test)
  s_pred_aod = pred_aod[0]

  print(f"s_pred_aod : {s_pred_aod}")

  if s_pred_aod < 0 :
    s_pred_aod = 0

  print(s_pred_time)

  s_pred_time_n = datetime.strptime(s_pred_time, '%Y-%m-%d %H:%M:%S')
  print(f"s_pred_time_n : {s_pred_time_n}")

  # DB insert into s_predict
  sql_state3 = f"insert into s_prediction values (null, {s_r_seq[0]}, '{s_pred_time_n}', {s_pred_aod[0]})"
  cursor = conn.cursor()
  cursor.execute(sql_state3)
  conn.commit()

  time.sleep(10)
# Out:
# s_r_now_aod : 227
# s_now_time : 2022-05-11 16:04:26
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:04:26
# s_pred_time_slice : 2022-05-11 17:04:2
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:04:2
# before_hour_aod : 0    317
# Name: r_aod, dtype: int64
# [[2.99e+01 0.00e+00 1.10e+00 6.94e+01 2.00e-01 0.00e+00 2.00e+03 3.12e+01
#   2.27e+02 3.17e+02]]
# s_pred_aod : [101.36677063]
# 2022-05-11 17:04:26
# s_pred_time_n : 2022-05-11 17:04:26
# s_r_now_aod : 227
# s_now_time : 2022-05-11 16:04:37
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:04:37
# s_pred_time_slice : 2022-05-11 17:04:3
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:04:3
# before_hour_aod : 0    317
# Name: r_aod, dtype: int64
# [[2.8400e+01 0.0000e+00 1.2000e+00 7.0500e+01 3.0000e-01 0.0000e+00
#   2.0001e+03 3.2100e+01 2.2700e+02 3.1700e+02]]
# s_pred_aod : [120.83755201]
# 2022-05-11 17:04:37
# s_pred_time_n : 2022-05-11 17:04:37
# s_r_now_aod : 226
# s_now_time : 2022-05-11 16:04:47
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:04:47
# s_pred_time_slice : 2022-05-11 17:04:4
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:04:4
# before_hour_aod : 0    317
# Name: r_aod, dtype: int64
# [[2.98e+01 0.00e+00 1.20e+00 7.06e+01 3.00e-01 0.00e+00 2.00e+03 3.15e+01
#   2.26e+02 3.17e+02]]
# s_pred_aod : [113.71935187]
# 2022-05-11 17:04:47
# s_pred_time_n : 2022-05-11 17:04:47
# s_r_now_aod : 226
# s_now_time : 2022-05-11 16:04:58
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:04:58
# s_pred_time_slice : 2022-05-11 17:04:5
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:04:5
# before_hour_aod : 0    316
# Name: r_aod, dtype: int64
# [[3.0000e+01 0.0000e+00 1.2000e+00 7.1100e+01 2.0000e-01 0.0000e+00
#   1.9999e+03 3.1200e+01 2.2600e+02 3.1600e+02]]
# s_pred_aod : [105.44985593]
# 2022-05-11 17:04:58
# s_pred_time_n : 2022-05-11 17:04:58
# s_r_now_aod : 226
# s_now_time : 2022-05-11 16:05:08
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:05:08
# s_pred_time_slice : 2022-05-11 17:05:0
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:05:0
# before_hour_aod : 0    316
# Name: r_aod, dtype: int64
# [[2.94e+01 0.00e+00 1.10e+00 7.00e+01 3.00e-01 0.00e+00 2.00e+03 3.10e+01
#   2.26e+02 3.16e+02]]
# s_pred_aod : [111.46862408]
# 2022-05-11 17:05:08
# s_pred_time_n : 2022-05-11 17:05:08
# s_r_now_aod : 225
# s_now_time : 2022-05-11 16:05:19
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:05:19
# s_pred_time_slice : 2022-05-11 17:05:1
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:05:1
# before_hour_aod : 0    316
# Name: r_aod, dtype: int64
# [[2.8600e+01 0.0000e+00 1.1000e+00 7.0500e+01 3.0000e-01 0.0000e+00
#   2.0001e+03 3.2100e+01 2.2500e+02 3.1600e+02]]
# s_pred_aod : [116.70209138]
# 2022-05-11 17:05:19
# s_pred_time_n : 2022-05-11 17:05:19
# s_r_now_aod : 225
# s_now_time : 2022-05-11 16:05:29
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:05:29
# s_pred_time_slice : 2022-05-11 17:05:2
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:05:2
# before_hour_aod : 0    316
# Name: r_aod, dtype: int64
# [[2.97e+01 0.00e+00 1.10e+00 6.94e+01 3.00e-01 0.00e+00 2.00e+03 3.20e+01
#   2.25e+02 3.16e+02]]
# s_pred_aod : [110.44870201]
# 2022-05-11 17:05:29
# s_pred_time_n : 2022-05-11 17:05:29
# s_r_now_aod : 225
# s_now_time : 2022-05-11 16:05:40
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:05:40
# s_pred_time_slice : 2022-05-11 17:05:4
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:05:4
# before_hour_aod : 0    315
# Name: r_aod, dtype: int64
# [[2.9000e+01 0.0000e+00 1.1000e+00 6.9500e+01 3.0000e-01 0.0000e+00
#   2.0001e+03 3.2100e+01 2.2500e+02 3.1500e+02]]
# s_pred_aod : [113.67789662]
# 2022-05-11 17:05:40
# s_pred_time_n : 2022-05-11 17:05:40
# s_r_now_aod : 224
# s_now_time : 2022-05-11 16:06:01
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:01
# s_pred_time_slice : 2022-05-11 17:06:0
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:0
# before_hour_aod : 0    315
# Name: r_aod, dtype: int64
# [[2.89e+01 0.00e+00 1.10e+00 6.93e+01 3.00e-01 0.00e+00 2.00e+03 3.33e+01
#   2.24e+02 3.15e+02]]
# s_pred_aod : [115.35241153]
# 2022-05-11 17:06:01
# s_pred_time_n : 2022-05-11 17:06:01
# s_r_now_aod : 223
# s_now_time : 2022-05-11 16:06:11
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:11
# s_pred_time_slice : 2022-05-11 17:06:1
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:1
# before_hour_aod : 0    314
# Name: r_aod, dtype: int64
# [[2.9000e+01 0.0000e+00 1.1000e+00 6.8800e+01 3.0000e-01 0.0000e+00
#   1.9999e+03 3.0000e+01 2.2300e+02 3.1400e+02]]
# s_pred_aod : [104.6459948]
# 2022-05-11 17:06:11
# s_pred_time_n : 2022-05-11 17:06:11
# s_r_now_aod : 223
# s_now_time : 2022-05-11 16:06:22
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:22
# s_pred_time_slice : 2022-05-11 17:06:2
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:2
# before_hour_aod : 0    314
# Name: r_aod, dtype: int64
# [[2.8900e+01 0.0000e+00 1.2000e+00 6.9500e+01 2.0000e-01 0.0000e+00
#   1.9999e+03 3.3100e+01 2.2300e+02 3.1400e+02]]
# s_pred_aod : [107.44355329]
# 2022-05-11 17:06:22
# s_pred_time_n : 2022-05-11 17:06:22
# s_r_now_aod : 223
# s_now_time : 2022-05-11 16:06:33
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:33
# s_pred_time_slice : 2022-05-11 17:06:3
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:3
# before_hour_aod : 0    314
# Name: r_aod, dtype: int64
# [[2.8300e+01 0.0000e+00 1.1000e+00 7.0900e+01 3.0000e-01 0.0000e+00
#   1.9999e+03 3.1000e+01 2.2300e+02 3.1400e+02]]
# s_pred_aod : [114.14880746]
# 2022-05-11 17:06:33
# s_pred_time_n : 2022-05-11 17:06:33
# s_r_now_aod : 222
# s_now_time : 2022-05-11 16:06:43
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:43
# s_pred_time_slice : 2022-05-11 17:06:4
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:4
# before_hour_aod : 0    314
# Name: r_aod, dtype: int64
# [[2.86e+01 0.00e+00 1.10e+00 7.00e+01 3.00e-01 0.00e+00 2.00e+03 3.25e+01
#   2.22e+02 3.14e+02]]
# s_pred_aod : [113.74521566]
# 2022-05-11 17:06:43
# s_pred_time_n : 2022-05-11 17:06:43
# s_r_now_aod : 222
# s_now_time : 2022-05-11 16:06:54
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:06:54
# s_pred_time_slice : 2022-05-11 17:06:5
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:06:5
# before_hour_aod : 0    313
# Name: r_aod, dtype: int64
# [[2.99e+01 0.00e+00 1.20e+00 6.90e+01 2.00e-01 0.00e+00 2.00e+03 3.32e+01
#   2.22e+02 3.13e+02]]
# s_pred_aod : [102.56965257]
# 2022-05-11 17:06:54
# s_pred_time_n : 2022-05-11 17:06:54
# s_r_now_aod : 222
# s_now_time : 2022-05-11 16:07:04
# s_pred_t : 17
# s_pred_time : 2022-05-11 17:07:04
# s_pred_time_slice : 2022-05-11 17:07:0
# s_before_t : 15
# s_before_time_slice : 2022-05-11 15:07:0
# before_hour_aod : Series([], Name: r_aod, dtype: object)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-4ef5315c2b32> in <module>()
#      64   # 모델에 넣을 데이터 형식 맞추기
#      65   after_hour_weather['now_aod'] = s_r_now_aod[0]
# ---> 66   after_hour_weather['before_aod'] = before_hour_aod[0]
#      67
#      68   test = after_hour_weather.loc[:, 'temperature':]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     937
#     938         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 939             return self._values[key]
#     940
#     941         elif key_is_scalar:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
