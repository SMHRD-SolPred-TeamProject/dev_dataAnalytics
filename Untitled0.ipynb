# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Colab\ Notebooks/2022-05-13\ 모델\ 생성\ 작업
# Out:
# /content/drive/MyDrive/Colab Notebooks/2022-05-13 모델 생성 작업

# %%
import pandas as pd
import numpy as np

# %%
weather_aod = pd.read_csv('./data/weather_aod_0505_0523.csv', encoding='utf-8')

# %%
insert_data = weather_aod.iloc[86400:, :]

# %%
insert_data = insert_data.drop([insert_data.columns[0], insert_data.columns[1]], axis=1)
insert_data
# Out:
#              date_time  temperature  precipitation  wind_speed   humidity  \
# 86400   05-15 00:00:00    19.136334       0.298076    0.265428  98.976558
# 86401   05-15 00:00:10    19.160584       0.539137    0.251898  99.036501
# 86402   05-15 00:00:20    19.308142       0.566037    0.294426  98.993968
# 86403   05-15 00:00:30    19.325926       0.444935    0.157153  99.071912
# 86404   05-15 00:00:40    19.165048       0.493333    0.284360  99.086987
# ...                ...          ...            ...         ...        ...
# 155516  05-22 23:59:20    21.920166       0.000000    0.063679  98.978736
# 155517  05-22 23:59:30    22.025666       0.000000    0.171538  99.084766
# 155518  05-22 23:59:40    21.930888       0.000000    0.092957  99.040640
# 155519  05-22 23:59:50    22.086412       0.000000    0.184221  99.034333
# 155520  05-23 00:00:00    21.939218       0.000000    0.061331  98.922225
#
#         radiation  total_cloudiness   visibility  ground_temp  aod
# ...

# %%
insert_data['mem_id'] = 'wish'

# %%
insert_data
# Out:
#              date_time  temperature  precipitation  wind_speed   humidity  \
# 86400   05-15 00:00:00    19.136334       0.298076    0.265428  98.976558
# 86401   05-15 00:00:10    19.160584       0.539137    0.251898  99.036501
# 86402   05-15 00:00:20    19.308142       0.566037    0.294426  98.993968
# 86403   05-15 00:00:30    19.325926       0.444935    0.157153  99.071912
# 86404   05-15 00:00:40    19.165048       0.493333    0.284360  99.086987
# ...                ...          ...            ...         ...        ...
# 155516  05-22 23:59:20    21.920166       0.000000    0.063679  98.978736
# 155517  05-22 23:59:30    22.025666       0.000000    0.171538  99.084766
# 155518  05-22 23:59:40    21.930888       0.000000    0.092957  99.040640
# 155519  05-22 23:59:50    22.086412       0.000000    0.184221  99.034333
# 155520  05-23 00:00:00    21.939218       0.000000    0.061331  98.922225
#
#         radiation  total_cloudiness   visibility  ground_temp  aod mem_id
# ...

# %%
insert_data.to_csv('./data/new_data.csv')

# %%
data = pd.read_csv('./data/new_data.csv', encoding='utf-8')
data
# Out:
#        Unnamed: 0       date_time  temperature  precipitation  wind_speed  \
# 0           86400  05-15 00:00:00    19.136334       0.298076    0.265428
# 1           86401  05-15 00:00:10    19.160584       0.539137    0.251898
# 2           86402  05-15 00:00:20    19.308142       0.566037    0.294426
# 3           86403  05-15 00:00:30    19.325926       0.444935    0.157153
# 4           86404  05-15 00:00:40    19.165048       0.493333    0.284360
# ...           ...             ...          ...            ...         ...
# 69116      155516  05-22 23:59:20    21.920166       0.000000    0.063679
# 69117      155517  05-22 23:59:30    22.025666       0.000000    0.171538
# 69118      155518  05-22 23:59:40    21.930888       0.000000    0.092957
# 69119      155519  05-22 23:59:50    22.086412       0.000000    0.184221
# 69120      155520  05-23 00:00:00    21.939218       0.000000    0.061331
#
#         humidity  radiation  total_cloudiness   visibility  ground_temp  aod  \
# ...

# %%
data = data.drop(data.columns[0], axis=1)
data
# Out:
#             date_time  temperature  precipitation  wind_speed   humidity  \
# 0      05-15 00:00:00    19.136334       0.298076    0.265428  98.976558
# 1      05-15 00:00:10    19.160584       0.539137    0.251898  99.036501
# 2      05-15 00:00:20    19.308142       0.566037    0.294426  98.993968
# 3      05-15 00:00:30    19.325926       0.444935    0.157153  99.071912
# 4      05-15 00:00:40    19.165048       0.493333    0.284360  99.086987
# ...               ...          ...            ...         ...        ...
# 69116  05-22 23:59:20    21.920166       0.000000    0.063679  98.978736
# 69117  05-22 23:59:30    22.025666       0.000000    0.171538  99.084766
# 69118  05-22 23:59:40    21.930888       0.000000    0.092957  99.040640
# 69119  05-22 23:59:50    22.086412       0.000000    0.184221  99.034333
# 69120  05-23 00:00:00    21.939218       0.000000    0.061331  98.922225
#
#        radiation  total_cloudiness   visibility  ground_temp  aod mem_id
# ...

# %%
data.to_csv('./data/insert_data.csv')

# %%
n_data = pd.read_csv('./data/insert_data.csv', encoding='utf-8')
n_data
# Out:
#        Unnamed: 0       date_time  temperature  precipitation  wind_speed  \
# 0               0  05-15 00:00:00    19.136334       0.298076    0.265428
# 1               1  05-15 00:00:10    19.160584       0.539137    0.251898
# 2               2  05-15 00:00:20    19.308142       0.566037    0.294426
# 3               3  05-15 00:00:30    19.325926       0.444935    0.157153
# 4               4  05-15 00:00:40    19.165048       0.493333    0.284360
# ...           ...             ...          ...            ...         ...
# 69116       69116  05-22 23:59:20    21.920166       0.000000    0.063679
# 69117       69117  05-22 23:59:30    22.025666       0.000000    0.171538
# 69118       69118  05-22 23:59:40    21.930888       0.000000    0.092957
# 69119       69119  05-22 23:59:50    22.086412       0.000000    0.184221
# 69120       69120  05-23 00:00:00    21.939218       0.000000    0.061331
#
#         humidity  radiation  total_cloudiness   visibility  ground_temp  aod  \
# ...

# %%
n_data.columns
# Out:
# Index(['Unnamed: 0', 'date_time', 'temperature', 'precipitation', 'wind_speed',
#        'humidity', 'radiation', 'total_cloudiness', 'visibility',
#        'ground_temp', 'aod', 'mem_id'],
#       dtype='object')

# %%
n_data.columns = ['r_seq', 'r_date', 'r_temperature', 'r_precipitation', 'r_wind', 'r_humidity', 'r_radiation', 'r_total_cloudiness', 'r_visibility', 'r_ground_temp', 'r_aod', 'mem_id']

# %%
n_data
# Out:
#        r_seq          r_date  r_temperature  r_precipitation    r_wind  \
# 0          0  05-15 00:00:00      19.136334         0.298076  0.265428
# 1          1  05-15 00:00:10      19.160584         0.539137  0.251898
# 2          2  05-15 00:00:20      19.308142         0.566037  0.294426
# 3          3  05-15 00:00:30      19.325926         0.444935  0.157153
# 4          4  05-15 00:00:40      19.165048         0.493333  0.284360
# ...      ...             ...            ...              ...       ...
# 69116  69116  05-22 23:59:20      21.920166         0.000000  0.063679
# 69117  69117  05-22 23:59:30      22.025666         0.000000  0.171538
# 69118  69118  05-22 23:59:40      21.930888         0.000000  0.092957
# 69119  69119  05-22 23:59:50      22.086412         0.000000  0.184221
# 69120  69120  05-23 00:00:00      21.939218         0.000000  0.061331
#
#        r_humidity  r_radiation  r_total_cloudiness  r_visibility  \
# ...

# %%
n_data.to_csv('./data/insert_data_final.csv')

# %%
n = pd.read_csv('./data/insert_data_final.csv', encoding='utf-8')
n
# Out:
#        Unnamed: 0  r_seq          r_date  r_temperature  r_precipitation  \
# 0               0      0  05-15 00:00:00      19.136334         0.298076
# 1               1      1  05-15 00:00:10      19.160584         0.539137
# 2               2      2  05-15 00:00:20      19.308142         0.566037
# 3               3      3  05-15 00:00:30      19.325926         0.444935
# 4               4      4  05-15 00:00:40      19.165048         0.493333
# ...           ...    ...             ...            ...              ...
# 69116       69116  69116  05-22 23:59:20      21.920166         0.000000
# 69117       69117  69117  05-22 23:59:30      22.025666         0.000000
# 69118       69118  69118  05-22 23:59:40      21.930888         0.000000
# 69119       69119  69119  05-22 23:59:50      22.086412         0.000000
# 69120       69120  69120  05-23 00:00:00      21.939218         0.000000
#
#          r_wind  r_humidity  r_radiation  r_total_cloudiness  r_visibility  \
# ...

# %%
for i in range(19120):
  day = n.loc[i, 'r_date']
  year = '2022'
  n.loc[i, 'r_date'] = f"{year}-{day}"
n
# Out:
#        Unnamed: 0  r_seq               r_date  r_temperature  r_precipitation  \
# 0               0      0  2022-05-15 00:00:00      19.136334         0.298076
# 1               1      1  2022-05-15 00:00:10      19.160584         0.539137
# 2               2      2  2022-05-15 00:00:20      19.308142         0.566037
# 3               3      3  2022-05-15 00:00:30      19.325926         0.444935
# 4               4      4  2022-05-15 00:00:40      19.165048         0.493333
# ...           ...    ...                  ...            ...              ...
# 69116       69116  69116       05-22 23:59:20      21.920166         0.000000
# 69117       69117  69117       05-22 23:59:30      22.025666         0.000000
# 69118       69118  69118       05-22 23:59:40      21.930888         0.000000
# 69119       69119  69119       05-22 23:59:50      22.086412         0.000000
# 69120       69120  69120       05-23 00:00:00      21.939218         0.000000
#
# ...

# %%
for i in range(19120):
  num = int(n.loc[i, 'r_seq'])
  n_num = num+1
  n.loc[i, 'r_seq'] = n_num
n
# Out:
#        Unnamed: 0  r_seq               r_date  r_temperature  r_precipitation  \
# 0               0      1  2022-05-15 00:00:00      19.136334         0.298076
# 1               1      2  2022-05-15 00:00:10      19.160584         0.539137
# 2               2      3  2022-05-15 00:00:20      19.308142         0.566037
# 3               3      4  2022-05-15 00:00:30      19.325926         0.444935
# 4               4      5  2022-05-15 00:00:40      19.165048         0.493333
# ...           ...    ...                  ...            ...              ...
# 69116       69116  69116       05-22 23:59:20      21.920166         0.000000
# 69117       69117  69117       05-22 23:59:30      22.025666         0.000000
# 69118       69118  69118       05-22 23:59:40      21.930888         0.000000
# 69119       69119  69119       05-22 23:59:50      22.086412         0.000000
# 69120       69120  69120       05-23 00:00:00      21.939218         0.000000
#
# ...

# %%
n.to_csv('./data/final_insert.csv')

# %%
n.loc[2, 'r_date']
# Out:
# '2022-05-15 00:00:20'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(n.loc[:, 'r_aod'])

# %%
n.iloc[1440, :]
# Out:
# Unnamed: 0                      1440
# r_seq                           1440
# r_date                05-15 04:00:00
# r_temperature              18.434424
# r_precipitation             0.039547
# r_wind                      0.551968
# r_humidity                 99.095241
# r_radiation                      0.0
# r_total_cloudiness           3.04202
# r_visibility              594.331951
# r_ground_temp              20.275111
# r_aod                            0.0
# mem_id                          wish
# Name: 1440, dtype: object

# %%
 n.isnull().sum()
# Out:
# Unnamed: 0            0
# r_seq                 0
# r_date                0
# r_temperature         0
# r_precipitation       0
# r_wind                0
# r_humidity            0
# r_radiation           0
# r_total_cloudiness    0
# r_visibility          0
# r_ground_temp         0
# r_aod                 0
# mem_id                0
# dtype: int64
